# %% [markdown]
# # **HR Attrition Project**
#
# # **Introduction and Methodology**
#
# The objective of this capstone project is to synthesize and apply the diverse skills and knowledge acquired throughout the coursework by developing an end-to-end data science solution focused on predicting employee attrition. The project integrates data exploration, feature engineering, machine learning, evaluation, and deployment, while emphasizing clear communication of results for business stakeholders.
#
# This is the first notebook of this repository. The structure implements a full pipeline from business problem framing to deployment: data ingestion and cleaning, exploratory data analysis, feature selection, model training (Logistic Regression, Decision Tree, Random Forest, XGBoost, Neural Networks), threshold optimization with business-focused recall targets, and a Gradio app (via app.py and space.yaml) for serving predictions.
#
#
# Group 10:
# - Filipe Brandão Carmo 20240828
# - João Silva 20241655
# - Rita Marques 20242019
# - Sara Henriques 20242070

# %% [markdown]
# # **The Business Problem**

# %% [markdown]
# High turnover rates are costly and disruptive, making it essential for HR to anticipate which employees are likely to leave. We are tasked with assisting a multinational consultancy firm in predicting employee attrition.
#
# The primary goal is to predict whether an employee will leave the company, based on the data provided. Secondary goals include identifying key factors influencing attrition and recommending strategies to retain valuable employees.
#
# The HR department and executive management will be the primary consumers of your insights, and they expect actionable recommendations based on your analysis.

# %% [markdown]
# # **Data Collection and Initial Processing**

# %% [markdown]
# The main goal of this notebook is to load the dataset provided by our client, that consists on a .csv file.
# This dataset contains various attributes related to employee demographics, job satisfaction, work experience, and compensation.

# %% [markdown]
# ### **1. Import libraries**

# %% [markdown]
# The following cell of code imports the necessary libraries used to project development.

# %%
import numpy as np ## pip install numpy==2.1 #need this to run ydata-profiling
import pandas as pd
import seaborn as sns
from scipy.stats import chi2_contingency # filter method
from sklearn.preprocessing import MinMaxScaler
from ydata_profiling import ProfileReport 
import matplotlib.pyplot as plt
from pathlib import Path



import sys
# !{sys.executable} -m pip install -U ydata-profiling[notebook]
# %pip install jupyter-contrib-nbextensions
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Requirement already satisfied: ydata-profiling[notebook] in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (4.18.0)
# Requirement already satisfied: scipy<1.17,>=1.8 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from ydata-profiling[notebook]) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from ydata-profiling[notebook]) (2.3.2)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from ydata-profiling[notebook]) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from ydata-profiling[notebook]) (2.12.3)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from ydata-profiling[notebook]) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from ydata-profiling[notebook]) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling[notebook]) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from ydata-profiling[notebook]) (2.1.0)
# Requirement already satisfied: minify-html>=0.15.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from ydata-profiling[notebook]) (0.16.4)
# Requirement already satisfied: filetype>=1.0.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from ydata-profiling[notebook]) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from ydata-profiling[notebook]) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from ydata-profiling[notebook]) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.66.3 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from ydata-profiling[notebook]) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from ydata-profiling[notebook]) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from ydata-profiling[notebook]) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from ydata-profiling[notebook]) (0.14.5)
# Requirement already satisfied: typeguard<5,>=4 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from ydata-profiling[notebook]) (4.4.4)
# Requirement already satisfied: imagehash==4.3.2 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from ydata-profiling[notebook]) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from ydata-profiling[notebook]) (1.9.4)
# Requirement already satisfied: dacite<2,>=1.9 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from ydata-profiling[notebook]) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from ydata-profiling[notebook]) (0.61.0)
# Requirement already satisfied: jupyter>=1.0.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from ydata-profiling[notebook]) (1.1.1)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from ydata-profiling[notebook]) (8.1.7)
# Requirement already satisfied: PyWavelets in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from imagehash==4.3.2->ydata-profiling[notebook]) (1.9.0)
# Requirement already satisfied: pillow in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from imagehash==4.3.2->ydata-profiling[notebook]) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling[notebook]) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from numba<0.63,>=0.60->ydata-profiling[notebook]) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling[notebook]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling[notebook]) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from phik<0.13,>=0.12.5->ydata-profiling[notebook]) (1.5.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=2->ydata-profiling[notebook]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=2->ydata-profiling[notebook]) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=2->ydata-profiling[notebook]) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=2->ydata-profiling[notebook]) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling[notebook]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling[notebook]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling[notebook]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling[notebook]) (2025.10.5)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling[notebook]) (1.0.1)
# Requirement already satisfied: colorama in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from tqdm<5,>=4.66.3->ydata-profiling[notebook]) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling[notebook]) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling[notebook]) (3.5)
# Requirement already satisfied: puremagic in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling[notebook]) (1.30)
# Requirement already satisfied: comm>=0.1.3 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (9.5.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (3.0.15)
# Requirement already satisfied: decorator in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.8.5)
# Requirement already satisfied: notebook in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (7.4.7)
# Requirement already satisfied: jupyter-console in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (7.16.6)
# Requirement already satisfied: ipykernel in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (6.30.1)
# Requirement already satisfied: jupyterlab in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (4.4.9)
# Requirement already satisfied: six>=1.5 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (1.17.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (1.8.17)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (5.8.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (7.1.0)
# Requirement already satisfied: pyzmq>=25 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (6.5.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (4.4.0)
# Requirement already satisfied: pywin32>=300 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (311)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (80.9.0)
# Requirement already satisfied: anyio in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (4.11.0)
# Requirement already satisfied: httpcore==1.* in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.23.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (3.0.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.9.0)
# Requirement already satisfied: babel>=2.10 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (4.25.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.27.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (4.0.0)
# Requirement already satisfied: rfc3339-validator in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (4.14.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2.21.2)
# Requirement already satisfied: lark>=1.2.2 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.3.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2.23)
# Requirement already satisfied: soupsieve>1.2 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (2.8)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2.9.0.20251008)
# Requirement already satisfied: executing>=1.2.0 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.3)
# Requirement already satisfied: jupyter-contrib-nbextensions in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (0.7.0)
# Requirement already satisfied: ipython_genutils in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-contrib-nbextensions) (0.2.0)
# Requirement already satisfied: jupyter_contrib_core>=0.3.3 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-contrib-nbextensions) (0.4.2)
# Requirement already satisfied: jupyter_core in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from jupyter-contrib-nbextensions) (5.8.1)
# Requirement already satisfied: jupyter_highlight_selected_word>=0.1.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-contrib-nbextensions) (0.2.0)
# Requirement already satisfied: jupyter_nbextensions_configurator>=0.4.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-contrib-nbextensions) (0.6.4)
# Requirement already satisfied: nbconvert>=6.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-contrib-nbextensions) (7.16.6)
# Requirement already satisfied: notebook>=6.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-contrib-nbextensions) (7.4.7)
# Requirement already satisfied: tornado in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from jupyter-contrib-nbextensions) (6.5.2)
# Requirement already satisfied: traitlets>=4.1 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from jupyter-contrib-nbextensions) (5.14.3)
# Requirement already satisfied: lxml in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-contrib-nbextensions) (6.0.2)
# Requirement already satisfied: setuptools in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter_contrib_core>=0.3.3->jupyter-contrib-nbextensions) (80.9.0)
# Requirement already satisfied: jupyter-server in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (2.17.0)
# Requirement already satisfied: pyyaml in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (6.0.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (4.14.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.0->jupyter-contrib-nbextensions) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (3.1.6)
# Requirement already satisfied: jupyterlab-pygments in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (5.10.4)
# Requirement already satisfied: packaging in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (25.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (2.19.2)
# Requirement already satisfied: webencodings in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.0->jupyter-contrib-nbextensions) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.0->jupyter-contrib-nbextensions) (1.4.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from jupyter_core->jupyter-contrib-nbextensions) (4.4.0)
# Requirement already satisfied: pywin32>=300 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from jupyter_core->jupyter-contrib-nbextensions) (311)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from nbclient>=0.5.0->nbconvert>=6.0->jupyter-contrib-nbextensions) (8.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=6.0->jupyter-contrib-nbextensions) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=6.0->jupyter-contrib-nbextensions) (27.1.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter-contrib-nbextensions) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter-contrib-nbextensions) (4.25.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter-contrib-nbextensions) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter-contrib-nbextensions) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter-contrib-nbextensions) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter-contrib-nbextensions) (0.27.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (2.27.3)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.9 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (4.4.9)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (0.2.4)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (4.11.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (0.5.3)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (0.23.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (3.0.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (1.9.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter-contrib-nbextensions) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter-contrib-nbextensions) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter-contrib-nbextensions) (6.30.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter-contrib-nbextensions) (2.3.0)
# Requirement already satisfied: certifi in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter-contrib-nbextensions) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter-contrib-nbextensions) (1.0.9)
# Requirement already satisfied: idna in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter-contrib-nbextensions) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter-contrib-nbextensions) (0.16.0)
# Requirement already satisfied: babel>=2.10 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (0.12.1)
# Requirement already satisfied: requests>=2.31 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from anyio>=3.1.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (25.1.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter-contrib-nbextensions) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter-contrib-nbextensions) (9.5.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter-contrib-nbextensions) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter-contrib-nbextensions) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter-contrib-nbextensions) (7.1.0)
# Requirement already satisfied: colorama in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter-contrib-nbextensions) (0.4.6)
# Requirement already satisfied: decorator in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter-contrib-nbextensions) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter-contrib-nbextensions) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter-contrib-nbextensions) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter-contrib-nbextensions) (3.0.52)
# Requirement already satisfied: stack_data in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter-contrib-nbextensions) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter-contrib-nbextensions) (0.8.5)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (4.0.0)
# Requirement already satisfied: rfc3339-validator in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (24.11.1)
# Requirement already satisfied: six>=1.5 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=6.0->jupyter-contrib-nbextensions) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (1.3.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (2.23)
# Requirement already satisfied: soupsieve>1.2 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter-contrib-nbextensions) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter-contrib-nbextensions) (4.15.0)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\saraesteveshenriques\appdata\local\programs\python\python313\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (2.9.0.20251008)
# Requirement already satisfied: executing>=1.2.0 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter-contrib-nbextensions) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter-contrib-nbextensions) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\saraesteveshenriques\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: console contrib dejavu events execute kernel kernelspec
# lab labextension labhub migrate nbconvert nbextensions_configurator notebook
# run server troubleshoot trust
#
# Jupyter command `jupyter-nbextension` not found.

# %% [markdown]
# ## **2. Import dataset**

# %% [markdown]
# The data for the project is available in this repository:
# - Path: EDSB25_10\EDSB25_10\data\raw\
# - Filename: HR_Attrition_Dataset.csv

# %%
#dataset available at: \EDSB25_10\EDSB25_10\data\raw\HR_Attrition_Dataset.csv
project_root = Path.cwd().parent

data_path = project_root / "data" / "raw" / "HR_Attrition_Dataset.csv"

HR = pd.read_csv(data_path)

# %% [markdown]
# #### Result DataFrame: HR

# %% [markdown]
# ## **3. Data Description**

# %% [markdown]
# The dataset is composed by 1470 lines and 35 columns. The following commands indicate that there are no missing values.
# Regarding data types it is possible to conclude that there are integers, floats and objects. When crossing the data types and the columns description it looks consistent.

# %%
print(f"The table has the following format: ", HR.shape)
print(HR.info(max_cols=35))
# Out:
# The table has the following format:  (1470, 35)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB
# None

# %% [markdown]
# ## **4. Explore data with ydata-profiling**

# %% [markdown]
# This section presents a data profile report about the different variables across the dataset.

# %%
#profile = ProfileReport(HR, title="Profiling Report") 
#profile

# %% [markdown]
# The dataset is composed with different variables that can be divided in 4 main categories:
# 1. **Employee demographics** - Age, Distance from Home, Gender, MaritalStatus
# 2. **Job characteristics** - Department, Business Travel (frequency), Daily Rate, Horly Rate, Montly Rate, Environment Satisfaction (on a scale from 1 to 4 where 1 means low), Job Involvement, Job Level, Job Role, Job Satisfaction, Over time, Relationship Satisfaction with the work, Training Times Last Year, Work life balance
# 3. **Work experience** - Education, Education Field, Number of Companies Worked, Total of Working Years, Years at the company, Years in the current role, Years since last promotion, Years with th current manager
# 4. **Compensation** -  MontlyIncome, Percent Salary Hike, Performance Rating, Stock Option Level

# %% [markdown]
# The exploration of the report above quickly indicates that there are features that don't have a significative value for the study, since are constants. It also highlights that there are no missing values.

# %% [markdown]
# ## **5. Preprocessing for Exploratory Data Analysis**

# %% [markdown]
# ### **5.1. Set index**

# %% [markdown]
# The analysis made previously allowed to undestand that EmployeeNumber had the potential to be used as index. Since those values are unique it will be used for that function.

# %%
unique_values = HR['EmployeeNumber'].is_unique
print (unique_values)
# Out:
# True

# %%
# Added to 
#pd.set_option('display.max_columns', None)
#HR.head(5)

# %%
#see the first 5 rows of the dataset with all columns
HR.set_index('EmployeeNumber', inplace = True)
HR.head(5)
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1                41       Yes      Travel_Rarely       1102
# 2                49        No  Travel_Frequently        279
# 4                37       Yes      Travel_Rarely       1373
# 5                33        No  Travel_Frequently       1392
# 7                27        No      Travel_Rarely        591
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1                                Sales                 1          2
# 2               Research & Development                 8          1
# 4               Research & Development                 2          2
# 5               Research & Development                 3          4
# 7               Research & Development                 2          1
#
#                EducationField  EmployeeCount  EnvironmentSatisfaction  ...  \
# EmployeeNumber                                                         ...
# 1               Life Sciences              1                        2  ...
# 2               Life Sciences              1                        3  ...
# 4                       Other              1                        4  ...
# 5               Life Sciences              1                        4  ...
# 7                     Medical              1                        1  ...
#
#                RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# EmployeeNumber
# 1                                     1             80                 0
# 2                                     4             80                 1
# 4                                     2             80                 0
# 5                                     3             80                 0
# 7                                     4             80                 1
#
#                 TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# EmployeeNumber
# 1                               8                     0                1
# 2                              10                     3                3
# 4                               7                     3                3
# 5                               8                     3                3
# 7                               6                     3                3
#
#                YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# EmployeeNumber
# 1                           6                   4                        0
# 2                          10                   7                        1
# 4                           0                   0                        0
# 5                           8                   7                        3
# 7                           2                   2                        2
#
#                 YearsWithCurrManager
# EmployeeNumber
# 1                                  5
# 2                                  7
# 4                                  0
# 5                                  0
# 7                                  2
#
# [5 rows x 34 columns]

# %% [markdown]
# ### **5.1. Check duplicates**

# %% [markdown]
# The command below was used to find duplicated lines - any register was found on those conditions.

# %%
HR[HR.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []
#
# [0 rows x 34 columns]

# %% [markdown]
# ### **5.2. Check missing values**

# %% [markdown]
# As indicated before there are no missing values on the features provided, however the following command is fully dedicated to check that.

# %%
HR.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %% [markdown]
# ### **5.3. Remove unvaluable features**

# %% [markdown]
# Based on the analysis performed in the 4th point of the present notebook,  where it was found that there are constant features, those features will be removed before moving on since they don't add value.

# %%
cleaned_for_eda = HR.drop(columns=['EmployeeCount', 'StandardHours', 'Over18'])

# %% [markdown]
# ## **6. Export the dataset after initial preprocessing**

# %% [markdown]
# The processed data is being saved to csv files available in the diretory \EDSB25_10\data\processed.

# %%
# 1. Get the current working directory (e.g., C:\...\EDSB25_10\EDSB25_10\notebooks)
current_dir = Path.cwd()


processed_dir = current_dir / "data" / "processed"

# 3. Create the directory structure if it doesn't exist
processed_dir.mkdir(parents=True, exist_ok=True)

# Export to CSV
output_path = processed_dir / "cleaned_for_eda.csv"
cleaned_for_eda.to_csv(output_path, index=True)

print(f"Saved cleaned_for_eda to: {output_path}")
# Out:
# Saved cleaned_for_eda to: c:\Projects\EDSB25_10\EDSB25_10\notebooks\data\processed\cleaned_for_eda.csv

# %% [markdown]
# #### Result DataFrame: cleaned_for_eda
# #### Result File: cleaned_for_eda.csv

# %% [markdown]
# The preprocess steps are available in the preprocessing_for_EDA.py
